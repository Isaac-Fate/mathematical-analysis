# %% [markdown]
# # Second Fundamental Theorem of Calculus

# %%
from pathlib import Path
import numpy as np
import scipy
from scipy.integrate import quad, romberg

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.axes import Axes

import seaborn as sns

sns.set_theme()
mpl.rc(
    "figure",
    dpi=150,
    # Use tight layout
    autolayout=True,
)
mpl.rc("text", usetex=True)
mpl.rc("font", family="Helvetica")


FIGURES_DIR = Path("../../tex/figures")
# Out:
# Bad value in file PosixPath('/Users/isaac/.matplotlib/stylelib/math.mplstyle'), line 14 ('axes.facecolor : #EAEAF2'): Key axes.facecolor: '' does not look like a color arg

# %%
f = lambda x: np.sin(x) / x
F = lambda x: np.sin(x) / 3

k = 10
x = np.linspace(0, np.pi * k, 1000)

ax: Axes
fig, ax = plt.subplots(1, 1)

y = f(x)
ax.plot(x, y)
ax.fill_between(x, 0, y, where=y >= 0, alpha=0.3)
ax.fill_between(x, y, 0, where=y < 0, alpha=0.3, color="tab:red")


xticks = list(map(lambda i: i * np.pi, np.arange(0, k + 1)))
xtick_labels = [0] + list(map(lambda i: r"$" + str(i) + r"\pi$", np.arange(1, k + 1)))
ax.set_xticks(xticks, labels=xtick_labels)


plt.show()

# fig.savefig(FIGURES_DIR / "change-of-variables-in-a-riemann-integral-example-1.png")
# Out:
# /var/folders/ys/b1hv6dln0t38g92zzgh9xgsw0000gn/T/ipykernel_64322/1664847302.py:1: RuntimeWarning: invalid value encountered in divide
#   f = lambda x: np.sin(x) / x
