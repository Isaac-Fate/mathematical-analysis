# %% [markdown]
# # The Function of Variable Upper Limit Integrals

# %%
from pathlib import Path
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.axes import Axes

import seaborn as sns

sns.set_theme()
mpl.rc(
    "figure",
    dpi=150,
    # Use tight layout
    autolayout=True,
)
mpl.rc("text", usetex=True)
mpl.rc("font", family="Helvetica")


FIGURES_DIR = Path("../../tex/figures")
# Out:
# Bad value in file PosixPath('/Users/isaac/.matplotlib/stylelib/math.mplstyle'), line 14 ('axes.facecolor : #EAEAF2'): Key axes.facecolor: '' does not look like a color arg

# %%
axs: np.ndarray[Axes]
fig, axs = plt.subplots(1, 2, figsize=(12.8, 4.8))

x = np.linspace(-1, 1, 500)
y = np.abs(x)

axs[0].plot(x, y, color="C0")
axs[0].set_title(r"$f(x)$")


y = 0.5 * (np.sign(x) * (x**2) + 1)

axs[1].plot(x, y, color="C1")
axs[1].set_title(r"$F(x)$")

plt.show()

fig.savefig(FIGURES_DIR / "absolute-value-function-and-its-antiderivative.png")

# %%
fig.get_size_inches()
